# %% [markdown]
# # 数理シミュレーション第9回課題

# %% [markdown]
# ## 1. SIRモデルを実装せよ。
# • 𝑆0 = 1000、𝐼0 = 1、𝑅0 = 0、𝜆 = 0.0004、 𝛾 = 0.2の場合
# • 𝑆0 = 100、𝐼0 = 1、𝑅0 = 0、𝜆 = 0.0004、 𝛾 = 0.2の場合で実行し、結果がスライドと同じになることを確認せよ。
# • SIRモデルのパラメータをいくつか変更し、変化のパターンを調べよ。

# %%
# 𝑆0 = 1000、𝐼0 = 1、𝑅0 = 0、𝜆 = 0.0004、 𝛾 = 0.2

from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, λ, γ):
    S,I,R = vars
    return -λ*S*I, λ*S*I-γ*I, γ*I

S0 = 1000       # Susceptible-感受性人口
I0 = 1          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.0004      # 係数λ-感染率
γ = 0.2         # 係数γ-回復率や隔離率
S,I,R = S0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,I,R],ts_ode,args=(λ,γ,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Removed",linestyle='-')
plt.legend()
plt.show()

# %%
# 𝑆0 = 100、𝐼0 = 1、𝑅0 = 0、𝜆 = 0.0004、 𝛾 = 0.2

from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, λ, γ):
    S,I,R = vars
    return -λ*S*I, λ*S*I-γ*I, γ*I

S0 = 100       # Susceptible-感受性人口
I0 = 1          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.0004      # 係数λ-感染率
γ = 0.2         # 係数γ-回復率や隔離率
S,I,R = S0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,I,R],ts_ode,args=(λ,γ,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Removed",linestyle='-')
plt.legend()
plt.show()

# %%
# 𝑆0 = 100、𝐼0 = 1、𝑅0 = 0、𝜆 = 0.0004、 𝛾 = 0.2

from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, λ, γ):
    S,I,R = vars
    return -λ*S*I, λ*S*I-γ*I, γ*I

S0 = 900       # Susceptible-感受性人口
I0 = 100          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.0001      # 係数λ-感染率
γ = 0.1         # 係数γ-回復率や隔離率
S,I,R = S0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,I,R],ts_ode,args=(λ,γ,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Removed",linestyle='-')
plt.legend()
plt.show()

S0 = 1500       # Susceptible-感受性人口
I0 = 10          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.0008      # 係数λ-感染率
γ = 0.2         # 係数γ-回復率や隔離率
S,I,R = S0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,I,R],ts_ode,args=(λ,γ,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Removed",linestyle='-')
plt.legend()
plt.show()

S0 = 800       # Susceptible-感受性人口
I0 = 200          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.001      # 係数λ-感染率
γ = 0.1         # 係数γ-回復率や隔離率
S,I,R = S0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,I,R],ts_ode,args=(λ,γ,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Removed",linestyle='-')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. [選択] SEIRモデルを実装せよ。SEIRモデルのパラメータをいくつか変更し、変化のパターンを調べよ。
# • 𝑆0 = 499、E0 = 1、𝐼0 = 0、𝑅0 = 0、𝜆 = 0.01、 𝛾 = 0.1、𝜀 = 0.2の場合で実行例を入れよ。

# %%
# S0 = 499, E0 = 1, I0 = 0, R0 = 0, lambda = 0.01, ɤ = 0.1, ε = 0.2

from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, λ, γ, ε):
    S,E,I,R = vars
    return -λ*S*I, λ*S*I-ε*E, ε*E-γ*I, γ*I

S0 = 499        # Susceptible-感受性人口
E0 = 1          # Exposed-潜伏期間
I0 = 0          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.01      # 係数λ-感染率
γ = 0.1         # 係数γ-回復率や隔離率
ε = 0.2        # 係数ε-発症率
S,E,I,R = S0,E0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,E,I,R],ts_ode,args=(λ,γ,ε,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Exposed",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,3],label="Removed",linestyle='-')
plt.legend()
plt.show()

# %%
# S0 = 499, E0 = 1, I0 = 0, R0 = 0, lambda = 0.001, ɤ = 0.1, ε = 0.3

from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, λ, γ, ε):
    S,E,I,R = vars
    return -λ*S*I, λ*S*I-ε*E, ε*E-γ*I, γ*I

S0 = 499        # Susceptible-感受性人口
E0 = 1          # Exposed-潜伏期間
I0 = 0          # Infections-感染人口
R0 = 0          # Removed-隔離された人口
λ = 0.001      # 係数λ-感染率
γ = 0.1         # 係数γ-回復率や隔離率
ε = 0.5        # 係数ε-発症率
S,E,I,R = S0,E0,I0,R0

ts_ode = np.arange(0.0, 100.0, 0.01)
S_ode = odeint(f,[S,E,I,R],ts_ode,args=(λ,γ,ε,))
plt.plot(ts_ode,S_ode[:,0],label="Susceptible",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Exposed",linestyle='-')
plt.plot(ts_ode,S_ode[:,2],label="Infections",linestyle='-')
plt.plot(ts_ode,S_ode[:,3],label="Removed",linestyle='-')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. [選択] 講義で学んだ以外の微分方程式を用いたシミュレーションを実装して結果を説明せよ。

# %% [markdown]
# ### 単振り子の運動
# - 単振り子の運動の微分方程式を用いたシミュレーションを行った.
# - 振り子の位置をθ、振り子の速度をωとした場合
#   - dθ/dt = ω
#   - dω/dt = -g*sin(θ)/L   (gは重力加速度,Lは振り子の長さ)

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, g, L):
    θ,ω = vars
    return ω, -(g/L)*np.sin(θ)

θ0 = np.pi/4     # 初期角度: π/4
ω0 = 0           # 初速度: 0
θ,ω = θ0,ω0
g = 9.80665      # 重力加速度: 9.80665
L = 1.0          # 振り子の長さ: 1

ts_ode = np.arange(0.0, 15.0, 0.01)
S_ode = odeint(f,[θ,ω],ts_ode,args=(g,L,))
plt.plot(ts_ode,S_ode[:,0],label="Angle: θ",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Angular V: ω",linestyle='-')
plt.xlabel("Time")
plt.ylabel("A")
plt.legend()
plt.show()
print("Maxθ:",np.max(S_ode))
# Out:
# Maxθ: 2.396767120579392

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, g, L):
    θ,ω = vars
    return ω, -(g/L)*np.sin(θ)

θ0 = np.pi/4     # 初期角度: π/4
ω0 = 0           # 初速度: 0
θ,ω = θ0,ω0
g = 9.80665      # 重力加速度: 9.80665
L = 0.5          # 振り子の長さ: 1

ts_ode = np.arange(0.0, 15.0, 0.01)
S_ode = odeint(f,[θ,ω],ts_ode,args=(g,L,))
plt.plot(ts_ode,S_ode[:,0],label="Angle: θ",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Angular V: ω",linestyle='-')
plt.xlabel("Time")
plt.ylabel("A")
plt.legend()
plt.show()
print("Maxθ:",np.max(S_ode[:,0]))
print("Maxω:",np.max(S_ode[:,1]))
# Out:
# Maxθ: 0.7853981633974483
# Maxω: 3.389570770563148

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

def f(vars, t, g, L):
    θ,ω = vars
    return ω, -(g/L)*np.sin(θ)

θ0 = np.pi/4     # 初期角度: π/4
ω0 = 5           # 初速度: 0
θ,ω = θ0,ω0
g = 9.80665      # 重力加速度: 9.80665
L = 0.5          # 振り子の長さ: 1

ts_ode = np.arange(0.0, 15.0, 0.01)
S_ode = odeint(f,[θ,ω],ts_ode,args=(g,L,))
plt.plot(ts_ode,S_ode[:,0],label="Angle: θ",linestyle='-')
plt.plot(ts_ode,S_ode[:,1],label="Angular V: ω",linestyle='-')
plt.xlabel("Time")
plt.ylabel("A")
plt.legend()
plt.show()
print("Maxθ:",np.max(S_ode[:,0]))
print("Maxω:",np.max(S_ode[:,1]))
# Out:
# Maxθ: 1.5009528006532344
# Maxω: 6.040616043137516
