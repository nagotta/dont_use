# %% [markdown]
# # 数理シミュレーション 課題7
#
# 1. ウサギとキツネの生態系のシミュレーションのプログラムを作成せよ。
# 𝐵𝑟 = 1，𝑎 = 0.1，𝑏 = 0.02，𝐷𝑓 = 1，𝑅 0 = 3 ，𝐹 0 = 1の場合でシミュレーションを実行せよ。

# %%
from scipy.integrate import odeint
Br = 1
a = 0.1
b = 0.02
Df = 1
R0 = 3
F0 = 1
R = R0
F = F0

def func1(vars, t, Br, a, b, Df):
    R,F = vars
    return (Br-a*F)*R, (b*R-Df)*F

import matplotlib.pyplot as plt
import numpy as np
ts_ode = np.arange(0.0, 14.0, 0.01)
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit",linestyle='--')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox",linestyle='--')

plt.legend()
plt.show()

# %% [markdown]
# 2. 係数𝑎の値は何を表していると考えられるか説明せよ。係数𝑎の値を𝑎 = 0.2などいくつか変更してシミュレーションを実行せよ。たとえば、係数𝑎 = 0.1の実行結果と比較するとどのように変わるか調べよ。

# %% [markdown]
# 係数aの値を大きくするとFox
# aはきつね(Fox)の個体数の減少に関する比例定数であると考えられる。

# %%
from scipy.integrate import odeint
Br = 1
a = 0.1
b = 0.02
Df = 1
R0 = 3
F0 = 1
R = R0
F = F0

def func1(vars, t, Br, a, b, Df):
    R,F = vars
    return (Br-a*F)*R, (b*R-Df)*F

import matplotlib.pyplot as plt
import numpy as np
ts_ode = np.arange(0.0, 20.0, 0.01)
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.1)",linestyle='--')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.1)",linestyle='--')

a = 0.2
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.2)",linestyle='-')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.2)",linestyle='-')

a = 0.3
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.3)",linestyle='-.')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.3)",linestyle='-.')

a = 0.4
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.4)",linestyle=':')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.4)",linestyle=':')



plt.legend()
plt.show()

# %% [markdown]
# 3. 係数𝑏の値は何を表していると考えられるか説明せよ。係数𝑏の値をいく

# %%
from scipy.integrate import odeint
Br = 1
a = 0.1
b = 0.02
Df = 1
R0 = 3
F0 = 1
R = R0
F = F0

def func1(vars, t, Br, a, b, Df):
    R,F = vars
    return (Br-a*F)*R, (b*R-Df)*F

import matplotlib.pyplot as plt
import numpy as np
ts_ode = np.arange(0.0, 20.0, 0.01)
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.1)",linestyle='--')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.1)",linestyle='--')

b = 0.03
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.2)",linestyle='-')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.2)",linestyle='-')

b = 0.04
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.3)",linestyle='-.')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.3)",linestyle='-.')

b = 0.05
Rs_ode = odeint(func1,[R,F],ts_ode,args=(Br,a,b,Df,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit(a=0.4)",linestyle=':')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox(a=0.4)",linestyle=':')



plt.legend()
plt.show()

# %% [markdown]
# 4. [任意] 3種の関係ではどうなるだろうか。たとえば、ウサギとキツネに 加えて、キツネを食べるオオカミがいた場合、3種の個体数の変化はど のようになるかプログラムを改良し、説明せ

# %% [markdown]
# W0とWを追加
# Bw:狼の出生率
# Df -> Dw:狼の死亡率
# c,d:比例定数
# W(t+Δt) - W(t) = (Bw - Dw)W(t)Δt
# 狐の死亡率 Df = cW(t)、狼の出生率Bw = dF(t)を用いて以下の式を表す
# F(t+Δt) = (1+(bR(t) - cW(t))Δt)F(t)
# W(t+Δt) = (1+(dF(t) - Dw)Δt)W(t)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

Br = 1
a = 0.1
b = 0.02
c = 0.2
d = 0.1
Dw = 1
R0 = 3
F0 = 2
W0 = 1
R = R0
F = F0
W = W0

def func1(vars, t, Br, a, b, c, d, Dw):
    R,F,W = vars
    return (Br-a*F)*R, (b*R-c*W)*F,(d*F-Dw)*W

ts_ode = np.arange(0.0, 30.0, 0.01)
Rs_ode = odeint(func1,[R0,F0,W0],ts_ode,args=(Br,a,b,c,d,Dw,))
plt.plot(ts_ode,Rs_ode[:,0],label="Rabbit",linestyle='-')
plt.plot(ts_ode,Rs_ode[:,1],label="Fox",linestyle='-')
plt.plot(ts_ode,Rs_ode[:,2],label="Wolf",linestyle='-')

plt.legend()
plt.show()
